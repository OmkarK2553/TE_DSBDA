# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
tc = df.corr()
sns.heatmap(tc,annot=True)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 5       18.7  394.12   5.21  28.7
# ..       ...     ...    ...   ...
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
#
# [394 rows x 14 columns]

# %%
df["AGE"] = df["AGE"].astype(int)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998   45  6.0622    3  222     18.7
# 5    0.02985   0.0   2.18   0.0  0.458  6.430   58  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...    ...  ...     ...  ...  ...      ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569   73  2.3999    6  391     19.2
# 500  0.22438   0.0   9.69   0.0  0.585  6.027   79  2.4982    6  391     19.2
# 502  0.04527   0.0  11.93   0.0  0.573  6.120   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794   89  2.3889    1  273     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 5    394.12   5.21  28.7
# ..      ...    ...   ...
# 499  395.77  15.10  17.5
# 500  396.90  14.33  16.8
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
#
# [394 rows x 14 columns]

# %%
X = df.drop(['MEDV'],axis=1)
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM  AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575   65  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421   78  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185   61  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998   45  6.0622    3  222     18.7
# 5    0.02985   0.0   2.18   0.0  0.458  6.430   58  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...    ...  ...     ...  ...  ...      ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569   73  2.3999    6  391     19.2
# 500  0.22438   0.0   9.69   0.0  0.585  6.027   79  2.4982    6  391     19.2
# 502  0.04527   0.0  11.93   0.0  0.573  6.120   76  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976   91  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794   89  2.3889    1  273     21.0
#
#           B  LSTAT
# 0    396.90   4.98
# 1    396.90   9.14
# 2    392.83   4.03
# 3    394.63   2.94
# 5    394.12   5.21
# ..      ...    ...
# 499  395.77  15.10
# 500  396.90  14.33
# 502  396.90   9.08
# 503  396.90   5.64
# 504  393.45   6.48
#
# [394 rows x 13 columns]

# %%
y = df["MEDV"]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 5      28.7
#        ...
# 499    17.5
# 500    16.8
# 502    20.6
# 503    23.9
# 504    22.0
# Name: MEDV, Length: 394, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (315, 13)
# (79, 13)
# (315,)
# (79,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 31.53946594627851

# %%
model.coef_
# Out:
# array([-1.40035639e-01,  5.24067915e-02,  9.08640454e-02,  3.04502279e+00,
#        -1.80920443e+01,  4.36659041e+00, -1.42502012e-02, -1.41229230e+00,
#         3.15538428e-01, -1.51389708e-02, -8.99047967e-01,  9.82652800e-03,
#        -4.15845684e-01])

# %%
coeff = pd.DataFrame([X_train.columns,model.coef_]).T
coeff = coeff.rename(columns={0:"Feature",1:"Coefficients"})
coeff
# Out:
#     Feature Coefficients
# 0      CRIM    -0.140036
# 1        ZN     0.052407
# 2     INDUS     0.090864
# 3      CHAS     3.045023
# 4       NOX   -18.092044
# 5        RM      4.36659
# 6       AGE     -0.01425
# 7       DIS    -1.412292
# 8       RAD     0.315538
# 9       TAX    -0.015139
# 10  PTRATIO    -0.899048
# 11        B     0.009827
# 12    LSTAT    -0.415846

# %%
model.score(X_test,y_test)
# Out:
# 0.7257691211693138

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([20.21680143, 12.86649002, 19.75455822, 15.73911648, 39.80021646,
#        24.61612148, 30.33126613, 14.65832206, 33.02602755, 20.44138382,
#        22.3064678 , 25.87356875, 24.62193574, 10.02591043, 25.56338395,
#        20.57517852, 17.96720268, 13.92594306, 22.06844663, 26.43907752,
#        16.47836202, 38.13056931, 27.41787812, 18.41611811, 15.64436533,
#        17.99179744, 20.36101964, 12.31069172,  2.85153822, 19.79880732,
#        36.40512176, 20.82256231, 19.91027997, 16.68045643, 32.40892112,
#        23.75115895, 17.09297222, 20.34672192, 19.04966257, 19.23069961,
#        32.24665451, 21.85934799, 34.94540899, 18.09355994, 17.37871058,
#        34.22092213, 18.69830408, 11.78430866, 13.87984499, 24.59507871,
#        22.79129902, 20.89865881, 20.67062267, 17.56802436, 22.09817788,
#        20.034711  , 27.93635353, 16.64686445, 24.882132  , 15.65317816,
#        17.08533974,  6.33535107, 17.05754698, 27.36515275, 23.65543935,
#        23.5063418 , 14.96179723,  0.98645415, 34.56238496, 23.07746774,
#         3.55968049,  8.2148731 , 19.81303515, 37.43580303, 25.93694674,
#        11.75324762, 40.60270335, 28.97117578, -4.97501395])

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print(r2)
print(mae)
print(mse)
print(rmse)
# Out:
# 0.7257691211693138
# 3.4777519060183955
# 25.129366502423608
# 5.012919957711634

# %%
sns.regplot(x=X.columns.all(),y=y,data=df)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>
