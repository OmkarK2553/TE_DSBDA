# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Student_Marks.csv")
# pd.DataFrame()

# %%
df
#print(df)
# Out:
#     number_courses  time_study   Marks Institute
# 0                3       4.508  19.202         A
# 1                4       0.096   7.734         B
# 2                4       3.133  13.811         A
# 3                6       7.909  53.018         B
# 4                8       7.811  55.299         C
# ..             ...         ...     ...       ...
# 95               6       3.561  19.128         B
# 96               3       0.301     NaN         C
# 97               4       7.163  41.444         A
# 98               7       0.309  12.027         B
# 99               3       6.335  32.357         C
#
# [100 rows x 4 columns]

# %%
print(df)
# Out:
#     number_courses  time_study   Marks Institute
# 0                3       4.508  19.202         A
# 1                4       0.096   7.734         B
# 2                4       3.133  13.811         A
# 3                6       7.909  53.018         B
# 4                8       7.811  55.299         C
# ..             ...         ...     ...       ...
# 95               6       3.561  19.128         B
# 96               3       0.301     NaN         C
# 97               4       7.163  41.444         A
# 98               7       0.309  12.027         B
# 99               3       6.335  32.357         C
#
# [100 rows x 4 columns]

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      95 non-null     float64
#  2   Marks           89 non-null     float64
#  3   Institute       99 non-null     object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.2+ KB

# %%
df.describe()
# Out:
#        number_courses  time_study      Marks
# count      100.000000   95.000000  89.000000
# mean         5.290000    4.121958  25.084910
# std          1.799523    2.368906  14.589906
# min          3.000000    0.096000   6.053000
# 25%          4.000000    2.101500  13.119000
# 50%          5.000000    4.067000  20.398000
# 75%          7.000000    6.185500  38.490000
# max          8.000000    7.957000  55.299000

# %%
df["Marks"].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# number_courses      int64
# time_study        float64
# Marks             float64
# Institute          object
# dtype: object

# %%
df["Marks"].min()
# Out:
# 6.053

# %%
np.min(df["Marks"])
# Out:
# 6.053

# %%
df["Marks"].max()
# Out:
# 55.299

# %%
df["Marks"].std()
# Out:
# 14.589905516112884

# %%
df["Institute"].unique()
# Out:
# array(['A', 'B', 'C', nan], dtype=object)

# %%
df["number_courses"].unique()
# Out:
# array([3, 4, 6, 8, 5, 7], dtype=int64)

# %%
df["number_courses"].value_counts()
# Out:
# 3    22
# 4    21
# 6    16
# 8    16
# 7    15
# 5    10
# Name: number_courses, dtype: int64

# %%
df.isnull()
# Out:
#     number_courses  time_study  Marks  Institute
# 0            False       False  False      False
# 1            False       False  False      False
# 2            False       False  False      False
# 3            False       False  False      False
# 4            False       False  False      False
# ..             ...         ...    ...        ...
# 95           False       False  False      False
# 96           False       False   True      False
# 97           False       False  False      False
# 98           False       False  False      False
# 99           False       False  False      False
#
# [100 rows x 4 columns]

# %%
df.loc[20:50:1]
# Out:
#     number_courses  time_study     Marks Institute
# 20               4       4.733  22.07300         B
# 21               6       6.126  35.93900         A
# 22               5       2.051  12.20900         B
# 23               7       4.875  25.08491         C
# 24               4       3.635  16.51700         B
# 25               3       1.407   6.62300         C
# 26               7       0.508  12.64700         C
# 27               8       4.378  26.53200         C
# 28               5       0.156   9.33300         B
# 29               4       1.299   8.83700         C
# 30               8       3.864  25.08491         B
# 31               3       1.923   8.10000         A
# 32               8       0.932  15.03800         A
# 33               6       6.594  39.96500         C
# 34               3       4.083  25.08491         A
# 35               3       7.543  43.97800         B
# 36               4       2.966  13.11900         B
# 37               6       7.283  46.45300         B
# 38               7       6.533  41.35800         C
# 39               6       7.775  51.14200         B
# 40               4       0.140  25.08491         C
# 41               6       2.754  15.72500         B
# 42               6       3.591  19.77100         B
# 43               5       1.557  10.42900         A
# 44               4       1.954   9.74200         A
# 45               3       2.061   8.92400         B
# 46               4       3.797  25.08491         C
# 47               4       4.779  22.70100         A
# 48               3       5.635  26.88200         B
# 49               5       3.913  19.10600         B
# 50               6       6.703  40.60200         C

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# Institute         0
# dtype: int64

# %%
df["number_courses"].fillna(value=df["number_courses"].mean(),inplace=True)
#df = df["number_courses"].fillna(value=df["number_courses"].mean())

# %%
df["time_study"].fillna(value=df["time_study"].mean(),inplace=True)

# %%
df["Marks"].fillna(value=df["Marks"].mean(),inplace=True)

# %%
df.isnull()
# Out:
#     number_courses  time_study  Marks  Institute
# 0            False       False  False      False
# 1            False       False  False      False
# 2            False       False  False      False
# 3            False       False  False      False
# 4            False       False  False      False
# ..             ...         ...    ...        ...
# 95           False       False  False      False
# 96           False       False  False      False
# 97           False       False  False      False
# 98           False       False  False      False
# 99           False       False  False      False
#
# [100 rows x 4 columns]

# %%
df["Institute"].value_counts().index[0]
# Out:
# 'B'

# %%
df["Institute"].fillna(value=df["Institute"].value_counts().index[0],inplace=True)
# a - 22
#  b- 56
# c = 43

#b,a,c

# %%
df
# Out:
#     number_courses  time_study     Marks Institute
# 0                3       4.508  19.20200         A
# 1                4       0.096   7.73400         B
# 2                4       3.133  13.81100         A
# 3                6       7.909  53.01800         B
# 4                8       7.811  55.29900         C
# ..             ...         ...       ...       ...
# 95               6       3.561  19.12800         B
# 96               3       0.301  25.08491         C
# 97               4       7.163  41.44400         A
# 98               7       0.309  12.02700         B
# 99               3       6.335  32.35700         C
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
#  3   Institute       100 non-null    object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.2+ KB

# %%
dummies = pd.get_dummies(df.Institute)

# %%
dummies
# Out:
#     A  B  C
# 0   1  0  0
# 1   0  1  0
# 2   1  0  0
# 3   0  1  0
# 4   0  0  1
# .. .. .. ..
# 95  0  1  0
# 96  0  0  1
# 97  1  0  0
# 98  0  1  0
# 99  0  0  1
#
# [100 rows x 3 columns]

# %%
merged = pd.concat([df,dummies],axis="columns")

# %%
merged
# Out:
#     number_courses  time_study     Marks Institute  A  B  C
# 0                3       4.508  19.20200         A  1  0  0
# 1                4       0.096   7.73400         B  0  1  0
# 2                4       3.133  13.81100         A  1  0  0
# 3                6       7.909  53.01800         B  0  1  0
# 4                8       7.811  55.29900         C  0  0  1
# ..             ...         ...       ...       ... .. .. ..
# 95               6       3.561  19.12800         B  0  1  0
# 96               3       0.301  25.08491         C  0  0  1
# 97               4       7.163  41.44400         A  1  0  0
# 98               7       0.309  12.02700         B  0  1  0
# 99               3       6.335  32.35700         C  0  0  1
#
# [100 rows x 7 columns]

# %%
merged = merged.drop(["Institute"],axis="columns")

# %%
merged
# Out:
#     number_courses  time_study     Marks  A  B  C
# 0                3       4.508  19.20200  1  0  0
# 1                4       0.096   7.73400  0  1  0
# 2                4       3.133  13.81100  1  0  0
# 3                6       7.909  53.01800  0  1  0
# 4                8       7.811  55.29900  0  0  1
# ..             ...         ...       ... .. .. ..
# 95               6       3.561  19.12800  0  1  0
# 96               3       0.301  25.08491  0  0  1
# 97               4       7.163  41.44400  1  0  0
# 98               7       0.309  12.02700  0  1  0
# 99               3       6.335  32.35700  0  0  1
#
# [100 rows x 6 columns]

# %%
merged["Marks"].dtype
# Out:
# dtype('float64')

# %%
merged["Marks"] = merged["Marks"].astype("string")

# %%
merged
# Out:
#     number_courses  time_study              Marks  A  B  C
# 0                3       4.508             19.202  1  0  0
# 1                4       0.096              7.734  0  1  0
# 2                4       3.133             13.811  1  0  0
# 3                6       7.909             53.018  0  1  0
# 4                8       7.811             55.299  0  0  1
# ..             ...         ...                ... .. .. ..
# 95               6       3.561             19.128  0  1  0
# 96               3       0.301  25.08491011235955  0  0  1
# 97               4       7.163             41.444  1  0  0
# 98               7       0.309             12.027  0  1  0
# 99               3       6.335             32.357  0  0  1
#
# [100 rows x 6 columns]

# %%
merged["Marks"].dtype
# Out:
# string[python]

# %%
pd.to_numeric(merged.Marks,downcast="signed")
# Out:
# 0     19.20200
# 1      7.73400
# 2     13.81100
# 3     53.01800
# 4     55.29900
#         ...
# 95    19.12800
# 96    25.08491
# 97    41.44400
# 98    12.02700
# 99    32.35700
# Name: Marks, Length: 100, dtype: float64

# %%
merged
# Out:
#     number_courses  time_study              Marks  A  B  C
# 0                3       4.508             19.202  1  0  0
# 1                4       0.096              7.734  0  1  0
# 2                4       3.133             13.811  1  0  0
# 3                6       7.909             53.018  0  1  0
# 4                8       7.811             55.299  0  0  1
# ..             ...         ...                ... .. .. ..
# 95               6       3.561             19.128  0  1  0
# 96               3       0.301  25.08491011235955  0  0  1
# 97               4       7.163             41.444  1  0  0
# 98               7       0.309             12.027  0  1  0
# 99               3       6.335             32.357  0  0  1
#
# [100 rows x 6 columns]

# %%
(merged["Marks"].values=="").sum()
# Out:
# 0

# %%
dummies2 = df.copy()

# %%
dummies2
# Out:
#     number_courses  time_study     Marks Institute
# 0                3       4.508  19.20200         A
# 1                4       0.096   7.73400         B
# 2                4       3.133  13.81100         A
# 3                6       7.909  53.01800         B
# 4                8       7.811  55.29900         C
# ..             ...         ...       ...       ...
# 95               6       3.561  19.12800         B
# 96               3       0.301  25.08491         C
# 97               4       7.163  41.44400         A
# 98               7       0.309  12.02700         B
# 99               3       6.335  32.35700         C
#
# [100 rows x 4 columns]

# %%
dummies2["Institute"].replace(["A","B","C"],[0,1,2],inplace=True)

# %%
dummies2
# Out:
#     number_courses  time_study     Marks  Institute
# 0                3       4.508  19.20200          0
# 1                4       0.096   7.73400          1
# 2                4       3.133  13.81100          0
# 3                6       7.909  53.01800          1
# 4                8       7.811  55.29900          2
# ..             ...         ...       ...        ...
# 95               6       3.561  19.12800          1
# 96               3       0.301  25.08491          2
# 97               4       7.163  41.44400          0
# 98               7       0.309  12.02700          1
# 99               3       6.335  32.35700          2
#
# [100 rows x 4 columns]

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
merged.plot.bar()
# Out:
# <AxesSubplot:>
